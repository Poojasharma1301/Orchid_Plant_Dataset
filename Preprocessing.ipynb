# %%
import cv2
import os

input_folder = r"C:\Users\Pooja\Documents\Orchid_Plant\Data\vanda"  # Replace with the path to your input folder
output_folder = 'GrayScale_vanda/'  # Replace with the path to your output folder
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
for filename in os.listdir(input_folder):
    if filename.endswith(('.jpg', '.png', '.jpeg')):  # Adjust the file extensions as needed
        image_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        # Read the image
        image = cv2.imread(image_path)
        # Convert to grayscale
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        # Save the grayscale image
        cv2.imwrite(output_path, gray_image)

print("Grayscale conversion complete.")
# Out:
# Grayscale conversion complete.

# %%
input_folder = r"C:\Users\Pooja\Documents\Orchid_Plant\GrayScale_vanda"  # Replace with the path to your input folder
output_folder = 'Normalization_vanda/'  # Replace with the path to your output folder
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
for filename in os.listdir(input_folder):
    if filename.endswith(('.jpg', '.png', '.jpeg')):  # Adjust the file extensions as needed
        image_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        # Read the image
        image = cv2.imread(image_path)
        # Convert to Normalize
        norm_image = (gray_image - np.min(gray_image)) / (np.max(gray_image) - np.min(gray_image))
        # Save the Normalize image
        cv2.imwrite(output_path, norm_image)

print("Normalization conversion complete.")
# Out:
# Normalization conversion complete.

# %%
input_folder = r"C:\Users\Pooja\Documents\Orchid_Plant\Data\vanda"  # Replace with the path to your input folder
output_folder = 'Resize_vanda/'  # Replace with the path to your output folder
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
for filename in os.listdir(input_folder):
    if filename.endswith(('.jpg', '.png', '.jpeg')):  # Adjust the file extensions as needed
        image_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        # Read the image
        image = cv2.imread(image_path)
        # Resize the image
        desired_size = (300, 300)  # Replace with your desired size
        resized_image = cv2.resize(image, desired_size)
        # Save the Resize image
        cv2.imwrite(output_path, resized_image)

print("Resizing conversion complete.")
# Out:
# Resizing conversion complete.

# %%
input_folder = r"C:\Users\Pooja\Documents\Orchid_Plant\Data\vanda"  # Replace with the path to your input folder
output_folder = 'GaussianBlur_vanda/'  # Replace with the path to your output folder
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
for filename in os.listdir(input_folder):
    if filename.endswith(('.jpg', '.png', '.jpeg')):  # Adjust the file extensions as needed
        image_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        # Read the image
        image = cv2.imread(image_path)
        # Apply Gaussian blur using OpenCV
        blur_radius = 5  # Adjust this value as needed
        blurred_image = cv2.GaussianBlur(image, (blur_radius, blur_radius), 0)
        # Save the Gaussian Blur image
        cv2.imwrite(output_path, blurred_image)

print("GaussianBlur conversion complete.")
# Out:
# GaussianBlur conversion complete.
